# %% [markdown]
# # 3.생일 데이터를 교재 코드를 이용해 힙으로 저장, 생일이 느린 순서로 10병 출력 코드

# %%
class Heap:
    def __init__(self):
        self.__A = []

    def insert(self, x):
        self.__A.append(x)
        self.__percolateUp(len(self.__A) - 1)

    def __percolateUp(self, i):
        parent = (i - 1) // 2
        if i > 0 and self.__A[i] > self.__A[parent]:
            self.__A[i], self.__A[parent] = self.__A[parent], self.__A[i]
            self.__percolateUp(parent)

    def deleteMax(self):
        if len(self.__A) == 0:
            return None
        else:
            max = self.__A[0]
            self.__A[0] = self.__A.pop()
            self.__percolateDown(0)
            return max

    def __percolateDown(self, i):
        left = 2 * i + 1
        right = 2 * i + 2
        largest = i

        if left < len(self.__A) and self.__A[left][0] > self.__A[largest][0]:
            largest = left
        if right < len(self.__A) and self.__A[right][0] > self.__A[largest][0]:
            largest = right
        if largest != i:
            self.__A[i], self.__A[largest] = self.__A[largest], self.__A[i]
            self.__percolateDown(largest)

filename = "DS_Birthdaydata - 시트1.csv"
heap = Heap()

with open(filename, encoding="utf-8") as f:
    next(f)  
    for line in f:
        try:
            code, name, birth = line.strip().split(",")
            if birth.strip() == "":
                continue
            birth_int = int(birth.strip())
            heap.insert((birth_int, code, name))
        except ValueError:
            continue 

print("생일이 가장 늦은 10명\n")
for i in range(10):
    item = heap.deleteMax()
    if item:
        birth, code, name = item
        print(f"{code} {name} ({birth})")
# Out:
# 생일이 가장 늦은 10명
#
# ******82 홍서연 (20241282)
# ******22 신수민 (20051230)
# ******42 이서영 (20051225)
# ******69 강민주 (20051214)
# ******78 김민경 (20051202)
# ******41 이서영 (20051112)
# ******17 배시은 (20051102)
# ******87 김여원 (20051031)
# ******44 이서진 (20051028)
# ******64 서홍빈 (20051024)

# %% [markdown]
# # 4.생일 데이터를 이용해 같은 조 친구들만 이름가 생년월일을 출력하는 코드

# %%
class BidirectNode:
    def __init__(self,x,prevNode:'bidirectNode',nextNode:'BidirectNode'):
        self.item=x
        self.prev=prevNode
        self.next=nextNode
class CircularDoublyLinkedList:
	def __init__(self):
		self.__head = BidirectNode("dummy", None, None)
		self.__head.prev = self.__head
		self.__head.next = self.__head
		self.__numItems = 0
	def insert(self, i:int, newItem) -> None:
		if (i >= 0 and i <= self.__numItems):
			prev = self.getNode(i - 1)
			newNode = BidirectNode(newItem, prev, prev.next)
			newNode.next.prev = newNode
			prev.next = newNode
			self.__numItems += 1
		else:
			print("index", i, ": out of bound in insert()") 

	def append(self, newItem) -> None:
		prev = self.__head.prev
		newNode = BidirectNode(newItem, prev, self.__head)
		prev.next = newNode
		self.__head.prev = newNode
		self.__numItems += 1

	def pop(self, *args):
		
		if self.isEmpty():
			return None
		if len(args) != 0: 
			i = args[0]
		if len(args) == 0 or i == -1:
			i = self.__numItems - 1
		if (i >= 0 and i <= self.__numItems - 1):
			curr = self.getNode(i)
			retItem = curr.item
			curr.prev.next = curr.next
			curr.next.prev = curr.prev
			self.__numItems -= 1
			return retItem
		else:
			return None
 
	def remove(self, x):
		curr = self.__findNode(x)
		if curr != None:
			curr.prev.next = curr.next
			curr.next.prev = curr.prev
			self.__numItems -= 1
			return x
		else:
			return None
	def get(self, *args):
		if self.isEmpty(): return None
		if len(args) != 0:  
			i = args[0]
		if len(args) == 0 or i == -1:
			i = self.__numItems - 1
		if (i >= 0 and i <= self.__numItems - 1):
			return self.getNode(i).item
		else:
			return None
 
	def index(self, x) -> int:
		cnt = 0
		for element in self:
			if element == x:
				return cnt
			cnt += 1
		return -12345

	def isEmpty(self) -> bool:
		return self.__numItems == 0
 
	def size(self) -> int:
		return self.__numItems
	
	def find_Node(self, x) -> BidirectNode:
		curr = self.__head.next 
		while curr != self.__head:
 
			if curr.item == x:
				return curr
			else:
				curr = curr.next
		return None

	def getNode(self, i:int) -> BidirectNode:
		curr = self.__head 
		for index in range(i + 1):
			curr = curr.next
		return curr

	def printList(self) -> None:
		for element in self:
			print(element, end = ' ')
		print()
	def __iter__(self):  
		return CircularDoublyLinkedListIterator(self)
 
class CircularDoublyLinkedListIterator:
	def __init__(self, alist):
		self.__head = alist.getNode(-1)  		
		self.iterPosition = self.__head.next  	
	def __next__(self):
		if self.iterPosition == self.__head: 	
			raise StopIteration
		else: 
			item = self.iterPosition.item
			self.iterPosition = self.iterPosition.next
			return item

filename = "DS_Birthdaydata - 시트1.csv"
circular_list = CircularDoublyLinkedList()

with open(filename, encoding="utf-8") as f:
    next(f)   
    for line in f:
        
        parts = line.strip().split(",")
        code = parts[0].strip()
        name = parts[1].strip()
        birth = parts[2].strip()
        circular_list.append((code, name, birth))

names =["이원진","박찬미","박혜린","전민서","임서영","이서현","안소민","이채민","이예림","이수빈","김효리","이지영","이진","김나림","이가연"]

for target_name in names:
    found = False
    for item in circular_list:
        code, name, birth = item
        if name == target_name:
            print(f"{name}의 생일은 {birth}입니다.")
            found = True
            break
# Out:
# 이원진의 생일은 20050602입니다.
# 박찬미의 생일은 20000507입니다.
# 박혜린의 생일은 20030603입니다.
# 전민서의 생일은 20040318입니다.
# 임서영의 생일은 20050207입니다.
# 이서현의 생일은 20040609입니다.
# 안소민의 생일은 20040420입니다.
# 이예림의 생일은 20021215입니다.
# 이수빈의 생일은 20040910입니다.
# 김효리의 생일은 20011212입니다.
# 이지영의 생일은 입니다.
# 이진의 생일은 20020415입니다.
# 김나림의 생일은 20030805입니다.
# 이가연의 생일은 20040927입니다.

# %% [markdown]
# # 5.교재 8장 우선순위 큐 연습문제

# %%
###1번.
최대 힙에서는 부모 노드가 반드시 자식 노드보다 큰 값을 가진다. 루트에 있는 원소의 깊이가 가장 얕다. 따라서 얕은 곳에 있는 원소가 더 깊은 곳에 있는 원소보다 더 작은 값을 
가질 수 없다.

###2번.
우선순위 큐는 완전이진트리이며 모든 노드가 자식노드보다 크거나 같다. 따라서 형제노드 간의 관계는 상관이 없다. 즉 A[n-1]이 가장 작은 값을 가질 수도 아닐 수도 있다.
(ex. 9784335 일 때 A[6]=5 이지만 가장 작은 값은 아니다.)

###3번.
완전이진트리에서 루트를 제거하며 서브트리(원소가 3개이하)를 만들어보면 된다. 다시 말해 n=6개 일때는 루트와 서브트리2개(원소 3개 이하)로 이루어진다.
따라서 서브트리 각각의 루트2개와 기존 루트 1개를 더한 3개가 루트의 자격으로 스며내리기를 하지 않아도 된다. 
n=11개 일 때는 처음 단계에 루트 1개와 원소7개의 서브트리, 원소 3개인 서브트리르 가진다. 
여기서 원소 7개의 서브 트리를 다시 루트와 원소3개의 서브트리 2개로 나누면 총 5개의 원소가 루트의 자격을 가지게 된다. 
n/2개의 원소가 루트의 자격으로 스며내리기 여부를 알아보지 않고 넘어간다.

###4번.
최악의 경우:Θ(logn), 최선의 경우: Θ(1)

###5번.
힙은 리스트로 구현되어 있기 때문에 마지막 원소를 pop()하면 쉽게 제거 가능하다.

###6번.
스며내리기를 반복하는 buildHeap()알고리즘은 (n/4)*(1*c)+(n/8)*(2*c)+ '' + 1*(logn * c) , 즉 O(n)의 수행시간을 가진다.
스며오리기는 삽입을 n번 반복하는 것과 같음으로 기존 삽입 작업의 수행시간 O(logn)을 n번 반복한 것, 즉 O(nlogn)의 수행시간을 가진다. 
스며내리기를 사용한 buildHeap()이 더 효율적이다.

###7번.
임의의 값이 증가되면 그 값을 스며오르기 하면 된다. 가장 마지막 원소의 값이 증가하게 되어 스며오르기 하면  Θ(logn)의 수행시간이 걸리고 이가 가장 최악의 경우이다.
즉 O(logn)

# %% [markdown]
# # 6.Leetcode 703.Kth Largest Element in Stream

# %%
class KthLargest:
    def __init__(self, k, nums):
        self.k = k
        self.heap = []

        for i in nums:
            self.add(i)

    def add(self, val):
        if len(self.heap) < self.k:
            self._heap_push(val)
        elif val > self.heap[0]:
            self._heap_pop()
            self._heap_push(val)
        return self.heap[0]

    def _heap_push(self, val):
        self.heap.append(val)
        self.__percolateUp(len(self.heap) - 1)

    def _heap_pop(self):
        last = self.heap.pop()
        if not self.heap:
            return
        self.heap[0] = last
        self.__percolateDown(0)

    def __percolateUp(self, i):
        parent = (i - 1) // 2
        if i>0 and self.heap[i] < self.heap[parent]:
            self.heap[i], self.heap[parent] = self.heap[parent], self.heap[i]
            self.__percolateUp(parent)

    def __percolateDown(self, i):
        n = len(self.heap)
        while True:
            smallest = i
            left = 2 * i + 1
            right = 2 * i + 2

            if left < n and self.heap[left] < self.heap[smallest]:
                smallest = left
            if right < n and self.heap[right] < self.heap[smallest]:
                smallest = right

            if smallest == i:
                break

            self.heap[i], self.heap[smallest] = self.heap[smallest], self.heap[i]
            i = smallest
